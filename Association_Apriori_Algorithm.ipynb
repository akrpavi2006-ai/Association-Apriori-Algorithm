# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv('/content/drive/MyDrive/AI/Market_Basket_Optimisation.csv',header=None)
d
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
d.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
d.isnull().sum()
# Out:
# 0        0
# 1     1754
# 2     3112
# 3     4156
# 4     4972
# 5     5637
# 6     6132
# 7     6520
# 8     6847
# 9     7106
# 10    7245
# 11    7347
# 12    7414
# 13    7454
# 14    7476
# 15    7493
# 16    7497
# 17    7497
# 18    7498
# 19    7500
# dtype: int64

# %%
transactions=[]
for i in range(0,len(d)):
  transactions.append([str(d.values[i,j]) for j in range(0,20)if str(d.values[i,j])!='NaN'])

# %%
# !pip install apyori

# %%
from apyori import apriori

# %%
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2,min_lift=3,min_length=2,max_length=2)

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
rows = []
for item in results:
    for rule in item.ordered_statistics:
        rows.append({s
            'Antecedent': ', '.join(rule.items_base),
            'Consequent': ', '.join(rule.items_add),
            'Support': round(item.support, 4),
            'Confidence': round(rule.confidence, 4),
            'Lift': round(rule.lift, 4)
        })
d = pd.DataFrame(rows)
d = d.sort_values(by='Lift', ascending=False).reset_index(drop=True)
d
# Out:
#              Antecedent   Consequent  Support  Confidence    Lift
# 0         fromage blanc        honey   0.0033      0.2451  5.1643
# 1           light cream      chicken   0.0045      0.2906  4.8440
# 2                 pasta     escalope   0.0059      0.3729  4.7008
# 3                 pasta       shrimp   0.0051      0.3220  4.5067
# 4     whole wheat pasta    olive oil   0.0080      0.2715  4.1224
# 5          tomato sauce  ground beef   0.0053      0.3774  3.8407
# 6  mushroom cream sauce     escalope   0.0057      0.3007  3.7908
# 7         herb & pepper  ground beef   0.0160      0.3235  3.2920
# 8           light cream    olive oil   0.0032      0.2051  3.1147
